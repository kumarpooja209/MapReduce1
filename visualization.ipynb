# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

#Importing data
df = pd.read_csv('D:\Scalable system programming\Output_new\wdata.csv')
#Printing head
print(df.head())

print(df.shape)
# Out:
#   holidays    temp  rain  snow  clouds weather weather_description  \
# 0     None  264.16   0.0   0.0       1   Clear        sky_is_clear
# 1     None  264.80   0.0   0.0      75  Clouds       broken_clouds
# 2     None  265.76   0.0   0.0      90  Clouds     overcast_clouds
# 3     None  267.61   0.0   0.0      40  Clouds    scattered_clouds
# 4     None  269.43   0.0   0.0       1   Clear        sky_is_clear
#
#           date_time  traffic        date
# 0  01/01/2016 07:00      882  01/01/2016
# 1  01/01/2016 08:00     1077  01/01/2016
# 2  01/01/2016 09:00     1574  01/01/2016
# 3  01/01/2016 10:00     2059  01/01/2016
# 4  01/01/2016 12:00     3206  01/01/2016
# (27853, 10)

# %%
import numpy as np
import pandas as pd
cr=pd.read_csv('D:\Scalable system programming\Output_new\wdata.csv')
cr_list=['temp','rain','traffic']
correlation=cr[cr_list].corr()
display(correlation)
# Out:
#              temp      rain   traffic
# temp     1.000000  0.010727  0.121574
# rain     0.010727  1.000000  0.006693
# traffic  0.121574  0.006693  1.000000

# %%
month= df[-513:]
print(month.head())
# Out:
#       holidays    temp  rain  snow  clouds       weather  \
# 27340     None  296.90   0.0   0.0      75        Clouds
# 27341     None  296.53   0.0   0.0      20        Clouds
# 27342     None  296.19   0.0   0.0       1         Clear
# 27343     None  296.10   0.0   0.0       1         Clear
# 27344     None  295.73   0.0   0.0       1  Thunderstorm
#
#           weather_description         date_time  traffic        date
# 27340           broken_clouds  15/09/2018 00:00     1179  15/09/2018
# 27341              few_clouds  15/09/2018 01:00      808  15/09/2018
# 27342            sky_is_clear  15/09/2018 02:00      584  15/09/2018
# 27343            sky_is_clear  15/09/2018 03:00      428  15/09/2018
# 27344  proximity_thunderstorm  15/09/2018 04:00      502  15/09/2018

# %%
m=month[-26:]

# %%
rain=df[-1200:]

# %%
rain.plot(x='date_time' , y='rain')
plt.title('Rainfall (50 days)')
plt.xlabel('Date & time')
plt.ylabel('Rainfall (in mm)')
plt.xticks(rotation=45)
# Out:
# (array([   0.,  200.,  400.,  600.,  800., 1000., 1200.]),
#  <a list of 7 Text xticklabel objects>)

# %%
m.plot(x='date_time' , y='traffic')
plt.title('Traffic Volume')
plt.xlabel('Date & time')
plt.ylabel('Traffic Volume')
plt.xticks(rotation=45)
# Out:
# (array([ 0.,  5., 10., 15., 20., 25.]), <a list of 6 Text xticklabel objects>)

# %%
m.plot(x='date_time' , y='temp')
plt.title('Temperature')
plt.xlabel('Date & time')
plt.ylabel('Temperature (in Kelvin)')
plt.xticks(rotation=45)
# Out:
# (array([ 0.,  5., 10., 15., 20., 25.]), <a list of 6 Text xticklabel objects>)

# %%
m.plot(x='date_time' , y='rain')
plt.title('RainFall')
plt.xlabel('Date & time')
plt.ylabel('Rainfall (in mm)')
plt.xticks(rotation=45)
# Out:
# (array([ 0.,  5., 10., 15., 20., 25.]), <a list of 6 Text xticklabel objects>)

# %%
m.plot(x='date_time' , y='clouds')
plt.title('Cloud Coverage')
plt.xlabel('Date & time')
plt.ylabel('cloud Coverage (%)')
plt.xticks(rotation=45)
# Out:
# (array([ 0.,  5., 10., 15., 20., 25.]), <a list of 6 Text xticklabel objects>)

# %%
month.plot(x='date_time' , y='traffic')
plt.title('Traffic Volume')
plt.xlabel('Date & time')
plt.ylabel('Traffic Volume')
plt.xticks(rotation=45)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text xticklabel objects>)

# %%
month.plot(x='date_time' , y='temp')
plt.title('Temperature')
plt.xlabel('Date & time')
plt.ylabel('Temperature (in Kelvin)')
plt.xticks(rotation=45)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text xticklabel objects>)

# %%
month.plot(x='date_time' , y='rain')
plt.title('Rainfall')
plt.xlabel('Date & time')
plt.ylabel('Rainfall (in mm)')
plt.xticks(rotation=45)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text xticklabel objects>)

# %%
month1=month[-200:]
month1.plot(x='date_time' , y='clouds')
plt.title('Cloud Coverage')
plt.xlabel('Date & time')
plt.ylabel('Cloud coverage (%)')
plt.xticks(rotation=45)
# Out:
# (array([  0.,  25.,  50.,  75., 100., 125., 150., 175., 200.]),
#  <a list of 9 Text xticklabel objects>)

# %%
traffic= month['date','traffic']
traffic.plot()

# %% [markdown]
# Reading output file and converting oit from text format to CSV format

# %%
import csv

dft1=pd.read_csv('D:\\Scalable system programming\\Output_new\\traffic_2.txt',delimiter = '\t',header=None)
dft1.columns = ['date','prediction']
dft1.to_csv (r'D:\\Scalable system programming\\Output_new\\traffic_2.csv', index=None)

# %%
dft2=pd.read_csv('D:\\Scalable system programming\\Output_new\\traffic_3.txt',delimiter = '\t',header=None)
dft2.columns = ['date','prediction']
dft2.to_csv (r'D:\\Scalable system programming\\Output_new\\traffic_3.csv', index=None)

# %%
dft3=pd.read_csv('D:\\Scalable system programming\\Output_new\\traffic_4.txt',delimiter = '\t',header=None)
dft3.columns = ['date','prediction']
dft3.to_csv (r'D:\\Scalable system programming\\Output_new\\traffic_4.csv', index=None)

# %%
dft4=pd.read_csv('D:\\Scalable system programming\\Output_new\\temp_3.txt',delimiter = '\t',header=None)
dft4.columns = ['date','prediction']
dft4.to_csv (r'D:\\Scalable system programming\\Output_new\\temp_3.csv', index=None)

# %%
dft5=pd.read_csv('D:\\Scalable system programming\\Output_new\\temp_5.txt',delimiter = '\t',header=None)
dft5.columns = ['date','prediction']
dft5.to_csv (r'D:\\Scalable system programming\\Output_new\\temp_5.csv', index=None)

# %%
dft6=pd.read_csv('D:\\Scalable system programming\\Output_new\\temp_7.txt',delimiter = '\t',header=None)
dft6.columns = ['date','prediction']
dft6.to_csv (r'D:\\Scalable system programming\\Output_new\\temp_7.csv', index=None)

# %%
dft7=pd.read_csv('D:\\Scalable system programming\\Output_new\\clouds_2.txt',delimiter = '\t',header=None)
dft7.columns = ['date','prediction']
dft7.to_csv (r'D:\\Scalable system programming\\Output_new\\clouds_2.csv', index=None)

# %%
dft8=pd.read_csv('D:\\Scalable system programming\\Output_new\\clouds_3.txt',delimiter = '\t',header=None)
dft8.columns = ['date','prediction']
dft8.to_csv (r'D:\\Scalable system programming\\Output_new\\clouds_3.csv', index=None)

# %%
dft9=pd.read_csv('D:\\Scalable system programming\\Output_new\\clouds_4.txt',delimiter = '\t',header=None)
dft9.columns = ['date','prediction']
dft9.to_csv (r'D:\\Scalable system programming\\Output_new\\clouds_4.csv', index=None)

# %%
dft10=pd.read_csv('D:\\Scalable system programming\\Output_new\\rain_2.txt',delimiter = '\t',header=None)
dft10.columns = ['date','prediction']
dft10.to_csv (r'D:\\Scalable system programming\\Output_new\\rain_2.csv', index=None)

# %%
dft11=pd.read_csv('D:\\Scalable system programming\\Output_new\\rain_3.txt',delimiter = '\t',header=None)
dft11.columns = ['date','prediction']
dft11.to_csv (r'D:\\Scalable system programming\\Output_new\\rain_3.csv', index=None)

# %%
dft12=pd.read_csv('D:\\Scalable system programming\\Output_new\\rain_4.txt',delimiter = '\t',header=None)
dft12.columns = ['date','prediction']
dft12.to_csv (r'D:\\Scalable system programming\\Output_new\\rain_4.csv', index=None)

# %% [markdown]
# ## Visualization of Traffic Volume Prediction

# %%
t2=pd.read_csv('D:\\Scalable system programming\\Output_new\\traffic_2.csv')
print(t2.head())
# Out:
#                date  prediction
# 0  01/01/2016 07:00       845.5
# 1  01/01/2016 08:00       979.5
# 2  01/01/2016 09:00      1325.5
# 3  01/01/2016 10:00      1816.5
# 4  01/01/2016 12:00      2632.5

# %%
traffic2=t2[-513:]
#traffic2.plot()
traffic2.plot(x='date' , y='prediction')
plt.title('Traffic_Volume Prediction (Window size 2)')
plt.xlabel('Date & time')
plt.ylabel('Traffic Volume')
plt.xticks(rotation=45)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text xticklabel objects>)

# %%
t3=pd.read_csv('D:\\Scalable system programming\\Output_new\\traffic_3.csv')
print(t3.head())
# Out:
#                date   prediction
# 0  01/01/2016 07:00   759.000000
# 1  01/01/2016 08:00   922.666667
# 2  01/01/2016 09:00  1177.666667
# 3  01/01/2016 10:00  1570.000000
# 4  01/01/2016 12:00  2279.666667

# %%
traffic3=t3[-513:]
#traffic2.plot()
traffic3.plot(x='date' , y='prediction')
plt.title('Traffic Volume Prediction (Window size 3)')
plt.xlabel('Date & time')
plt.ylabel('Traffic Volume')
plt.xticks(rotation=45)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text xticklabel objects>)

# %%
t4=pd.read_csv('D:\\Scalable system programming\\Output_new\\traffic_4.csv')
print(t4.head())
# Out:
#                date  prediction
# 0  01/01/2016 07:00       702.5
# 1  01/01/2016 08:00       838.5
# 2  01/01/2016 09:00      1085.5
# 3  01/01/2016 10:00      1398.0
# 4  01/01/2016 12:00      1979.0

# %%
traffic4=t4[-513:]
#traffic2.plot()
traffic4.plot(x='date' , y='prediction')
plt.title('Traffic Volume Prediction (Window size 4)')
plt.xlabel('Date & time')
plt.ylabel('Traffic Volume')
plt.xticks(rotation=45)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text xticklabel objects>)

# %%
actual_traffic= df['traffic']

# %%
traffic_2=t2['prediction']

# %%
traffic_3=t3['prediction']

# %%
traffic_4=t4['prediction']

# %%
from dm_test import dm_test
print("Comparison of MSE")
traffic1=dm_test(actual_traffic,traffic_3,traffic_2,h = 1, crit="MSE")
print("Comparison between window size 2 and 3 ",traffic1)
traffic2=dm_test(actual_traffic,traffic_4,traffic_3,h = 1, crit="MSE")
print("Comparison between window size 3 and 4 ",traffic2)
traffic3=dm_test(actual_traffic,traffic_4,traffic_2,h = 1, crit="MSE")
print("Comparison between window size 4 and 2 ",traffic3)
# Out:
# Comparison of MSE
# Comparison between window size 2 and 3  dm_return(DM=72.64121956900364, p_value=0.0)
# Comparison between window size 3 and 4  dm_return(DM=80.36410367279322, p_value=0.0)
# Comparison between window size 4 and 2  dm_return(DM=79.56578739782164, p_value=0.0)

# %%
##Mean absolute deviation 
print("Comparison of MAD")
traffic1=dm_test(actual_traffic,traffic_3,traffic_2,h = 1, crit="MAD")
print("Comparison between window size 2 and 3 ",traffic1)
traffic2=dm_test(actual_traffic,traffic_4,traffic_3,h = 1, crit="MAD")
print("Comparison between window size 3 and 4 ",traffic2)
traffic3=dm_test(actual_traffic,traffic_4,traffic_2,h = 1, crit="MAD")
print("Comparison between window size 4 and 2 ",traffic3)
# Out:
# Comparison of MAD
# Comparison between window size 2 and 3  dm_return(DM=137.16310879813292, p_value=0.0)
# Comparison between window size 3 and 4  dm_return(DM=142.87684150032925, p_value=0.0)
# Comparison between window size 4 and 2  dm_return(DM=153.646845196351, p_value=0.0)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error(actual_traffic, traffic_2)
rmse = sqrt(mse)
print("The RMSE value of Traffic for window size 2 is",rmse)
mse1 = mean_squared_error(actual_traffic, traffic_3)
rmse1 = sqrt(mse1)
print("The RMSE value of Traffic for window size 3 is",rmse1)
mse2 = mean_squared_error(actual_traffic, traffic_4)
rmse2 = sqrt(mse2)
print("The RMSE value of Traffic for window size 4 is",rmse2)
# Out:
# The RMSE value of Traffic for window size 2 is 392.49654300487634
# The RMSE value of Traffic for window size 3 is 684.1214044499031
# The RMSE value of Traffic for window size 4 is 925.411791528425

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(actual_traffic, traffic_2)
print("The MAE value of Traffic for window size 2 is",mae)
mae1 = mean_absolute_error(actual_traffic, traffic_3)
print("The MAE value of Traffic for window size 3 is",mae1)
mae2 = mean_absolute_error(actual_traffic, traffic_4)
print("The MAE value of Traffic for window size 4 is",mae2)
# Out:
# The MAE value of Traffic for window size 2 is 252.33721681685995
# The MAE value of Traffic for window size 3 is 467.7855766589907
# The MAE value of Traffic for window size 4 is 661.2337180914085

# %% [markdown]
# ## Visualisation of Temperature predictions

# %%
te3=pd.read_csv('D:\\Scalable system programming\\Output_new\\temp_3.csv')
print(te3.head())
# Out:
#                date  prediction
# 0  01/01/2016 07:00  264.176667
# 1  01/01/2016 08:00  264.316667
# 2  01/01/2016 09:00  264.906667
# 3  01/01/2016 10:00  266.056667
# 4  01/01/2016 12:00  267.600000

# %%
temp3=te3[-513:]
#traffic2.plot()
temp3.plot(x='date' , y='prediction')
plt.title('Temperature Prediction (Window Size 3)')
plt.xlabel('Date & time')
plt.ylabel('Temperature (in Kelvin)')
plt.xticks(rotation=45)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text xticklabel objects>)

# %%
te5=pd.read_csv('D:\\Scalable system programming\\Output_new\\temp_5.csv')
print(te5.head())
# Out:
#                date  prediction
# 0  01/01/2016 07:00     264.668
# 1  01/01/2016 08:00     264.426
# 2  01/01/2016 09:00     264.618
# 3  01/01/2016 10:00     265.264
# 4  01/01/2016 12:00     266.352

# %%
temp5=te5[-513:]
#traffic2.plot()
temp3.plot(x='date' , y='prediction')
plt.title('Temperature Prediction (Window size 5)')
plt.xlabel('Date & time')
plt.ylabel('Temperature (in Kelvin)')
plt.xticks(rotation=45)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text xticklabel objects>)

# %%
te7=pd.read_csv('D:\\Scalable system programming\\Output_new\\temp_7.csv')
print(te7.head())
# Out:
#                date  prediction
# 0  01/01/2016 07:00  265.040000
# 1  01/01/2016 08:00  264.877143
# 2  01/01/2016 09:00  264.842857
# 3  01/01/2016 10:00  265.071429
# 4  01/01/2016 12:00  265.732857

# %%
temp7=te7[-513:]

temp3.plot(x='date' , y='prediction')
plt.title('Temperature Prediction (Window size 7)')
plt.xlabel('Date & time')
plt.ylabel('Temperature (in Kelvin)')
plt.xticks(rotation=45)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text xticklabel objects>)

# %%
actual_temp= df['temp']

# %%
temp_3=te3['prediction']

# %%
temp_5=te5['prediction']

# %%
temp_7=te7['prediction']

# %%
from dm_test import dm_test
print("Comparison of MSE")
temp1=dm_test(actual_temp,temp_5,temp_3,h = 1, crit="MSE")
print("Comparison between window size 3 and 5",temp1)
temp2=dm_test(actual_temp,temp_7,temp_5,h = 1, crit="MSE")
print("Comparison between window size 5 and 7",temp2)
temp3=dm_test(actual_temp,temp_7,temp_3,h = 1, crit="MSE")
print("Comparison between window size 7 and 3",temp3)
# Out:
# Comparison of MSE
# Comparison between window size 3 and 5 dm_return(DM=85.85704642953719, p_value=0.0)
# Comparison between window size 5 and 7 dm_return(DM=91.45706957621267, p_value=0.0)
# Comparison between window size 7 and 3 dm_return(DM=93.77215443473128, p_value=0.0)

# %%
print("Comparison of MAD")
temp1=dm_test(actual_temp,temp_5,temp_3,h = 1, crit="MAD")
print("Comparison between window size 3 and 5",temp1)
temp2=dm_test(actual_temp,temp_7,temp_5,h = 1, crit="MAD")
print("Comparison between window size 5 and 7",temp2)
temp3=dm_test(actual_temp,temp_7,temp_3,h = 1, crit="MAD")
print("Comparison between window size 7 and 3",temp3)
# Out:
# Comparison of MAD
# Comparison between window size 3 and 5 dm_return(DM=151.96957937110466, p_value=0.0)
# Comparison between window size 5 and 7 dm_return(DM=139.98124043334707, p_value=0.0)
# Comparison between window size 7 and 3 dm_return(DM=157.0450173912241, p_value=0.0)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error(actual_temp, temp_3)
rmse = sqrt(mse)
print("The RMSE value of Temperature for window size 3 is",rmse)
mse1 = mean_squared_error(actual_temp, temp_5)
rmse1 = sqrt(mse1)
print("The RMSE value of Temperature for window size 5 is",rmse1)
mse2 = mean_squared_error(actual_temp, temp_7)
rmse2 = sqrt(mse2)
print("The RMSE value of Temperature for window size 7 is",rmse2)
# Out:
# The RMSE value of Temperature for window size 3 is 0.9076475526325316
# The RMSE value of Temperature for window size 5 is 1.6389415260721614
# The RMSE value of Temperature for window size 7 is 2.25684189743523

# %%
mae = mean_absolute_error(actual_temp, temp_3)
print("The MAE value of Temperature for window size 3 is",mae)
mae1 = mean_absolute_error(actual_temp, temp_5)
print("The MAE value of Temperature for window size 5 is",mae1)
mae2 = mean_absolute_error(actual_temp, temp_7)
print("The MAE value of Temperature for window size 7 is",mae2)
# Out:
# The MAE value of Temperature for window size 3 is 0.6140210868954867
# The MAE value of Temperature for window size 5 is 1.1639982335834558
# The MAE value of Temperature for window size 7 is 1.647229700969375

# %% [markdown]
# ## Visualization of Cloud coverage prediction

# %%
c2=pd.read_csv('D:\\Scalable system programming\\Output_new\\clouds_2.csv')
print(c2.head())
# Out:
#                date  prediction
# 0  01/01/2016 07:00         1.0
# 1  01/01/2016 08:00        38.0
# 2  01/01/2016 09:00        82.5
# 3  01/01/2016 10:00        65.0
# 4  01/01/2016 12:00        20.5

# %%
cloud2=c2[-200:]

cloud2.plot(x='date' , y='prediction')
plt.title('Clouds Coverage Prediction (Window size 2)')
plt.xlabel('Date & time')
plt.ylabel('Cloud coverage (%)')
plt.xticks(rotation=45)
# Out:
# (array([  0.,  25.,  50.,  75., 100., 125., 150., 175., 200.]),
#  <a list of 9 Text xticklabel objects>)

# %%
c3=pd.read_csv('D:\\Scalable system programming\\Output_new\\clouds_3.csv')
print(c3.head())
# Out:
#                date  prediction
# 0  01/01/2016 07:00   30.666667
# 1  01/01/2016 08:00   25.666667
# 2  01/01/2016 09:00   55.333333
# 3  01/01/2016 10:00   68.333333
# 4  01/01/2016 12:00   43.666667

# %%
cloud3=c3[-200:]

cloud3.plot(x='date' , y='prediction')
plt.title('Clouds Coverage Prediction (Window size 3)')
plt.xlabel('Date & time')
plt.ylabel('Cloud coverage (%)')
plt.xticks(rotation=45)
# Out:
# (array([  0.,  25.,  50.,  75., 100., 125., 150., 175., 200.]),
#  <a list of 9 Text xticklabel objects>)

# %%
c4=pd.read_csv('D:\\Scalable system programming\\Output_new\\clouds_4.csv')
print(c4.head())
# Out:
#                date  prediction
# 0  01/01/2016 07:00       45.50
# 1  01/01/2016 08:00       41.75
# 2  01/01/2016 09:00       41.75
# 3  01/01/2016 10:00       51.50
# 4  01/01/2016 12:00       51.50

# %%
cloud4=c4[-200:]

cloud4.plot(x='date' , y='prediction')
plt.title('Clouds Coverage Prediction (Window size 4)')
plt.xlabel('Date & time')
plt.ylabel('Cloud coverage (%)')
plt.xticks(rotation=45)
# Out:
# (array([  0.,  25.,  50.,  75., 100., 125., 150., 175., 200.]),
#  <a list of 9 Text xticklabel objects>)

# %%
actual_clouds= df['clouds']

# %%
clouds_2=c2['prediction']

# %%
clouds_3=c3['prediction']

# %%
clouds_4=c4['prediction']

# %%
from dm_test import dm_test
print("Comparison of MSE")
clouds1=dm_test(actual_clouds,clouds_3,clouds_2,h = 1, crit="MSE")
print("Comparison between window size 2 and 3",clouds1)
clouds2=dm_test(actual_clouds,clouds_4,clouds_3,h = 1, crit="MSE")
print("Comparison between window size 3 and 4",clouds2)
clouds3=dm_test(actual_clouds,clouds_4,clouds_2,h = 1, crit="MSE")
print("Comparison between window size 7 and 3",clouds3)
# Out:
# Comparison of MSE
# Comparison between window size 2 and 3 dm_return(DM=52.11679237616971, p_value=0.0)
# Comparison between window size 3 and 4 dm_return(DM=48.205658545329264, p_value=0.0)
# Comparison between window size 7 and 3 dm_return(DM=61.05027058707589, p_value=0.0)

# %%
print("Comparison of MAD")
clouds1=dm_test(actual_clouds,clouds_3,clouds_2,h = 1, crit="MAD")
print("Comparison between window size 2 and 3",clouds1)
clouds2=dm_test(actual_clouds,clouds_4,clouds_3,h = 1, crit="MAD")
print("Comparison between window size 3 and 4",clouds2)
clouds3=dm_test(actual_clouds,clouds_4,clouds_2,h = 1, crit="MAD")
print("Comparison between window size 7 and 3",clouds3)
# Out:
# Comparison of MAD
# Comparison between window size 2 and 3 dm_return(DM=67.23426568347365, p_value=0.0)
# Comparison between window size 3 and 4 dm_return(DM=61.749633830878814, p_value=0.0)
# Comparison between window size 7 and 3 dm_return(DM=82.5745079305304, p_value=0.0)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error(actual_clouds, clouds_2)
rmse = sqrt(mse)
print("The RMSE value of Clouds for window size 2 is",rmse)
mse1 = mean_squared_error(actual_clouds, clouds_3)
rmse1 = sqrt(mse1)
print("The RMSE value of Clouds for window size 3 is",rmse1)
mse2 = mean_squared_error(actual_clouds, clouds_4)
rmse2 = sqrt(mse2)
print("The RMSE value of Clouds for window size 4 is",rmse2)
# Out:
# The RMSE value of Clouds for window size 2 is 12.060850144181765
# The RMSE value of Clouds for window size 3 is 15.839911842977294
# The RMSE value of Clouds for window size 4 is 18.286075282102086

# %%
mae = mean_absolute_error(actual_clouds, clouds_2)
print("The MAE value of Clouds for window size 2 is",mae)
mae1 = mean_absolute_error(actual_clouds, clouds_3)
print("The MAE value of Clouds for window size 3 is",mae1)
mae2 = mean_absolute_error(actual_clouds, clouds_4)
print("The MAE value of Clouds for window size 4 is",mae2)
# Out:
# The MAE value of Clouds for window size 2 is 5.382741535920727
# The MAE value of Clouds for window size 3 is 8.289364401267584
# The MAE value of Clouds for window size 4 is 10.355679819050012

# %% [markdown]
# ## Visualization of Rainfall prediction

# %%
rain2=pd.read_csv('D:\\Scalable system programming\\Output_new\\rain_2.csv')
print(rain2.head())
# Out:
#                date  prediction
# 0  01/01/2016 07:00         0.0
# 1  01/01/2016 08:00         0.0
# 2  01/01/2016 09:00         0.0
# 3  01/01/2016 10:00         0.0
# 4  01/01/2016 12:00         0.0

# %%
r2=rain2[-513:]

r2.plot(x='date' , y='prediction')
plt.title('Rainfall Prediction (Window size 2)')
plt.xlabel('Date & time')
plt.ylabel('Rainfall (in mm)')
plt.xticks(rotation=45)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text xticklabel objects>)

# %%
rain3=pd.read_csv('D:\\Scalable system programming\\Output_new\\rain_3.csv')
print(rain3.head())
# Out:
#                date  prediction
# 0  01/01/2016 07:00         0.0
# 1  01/01/2016 08:00         0.0
# 2  01/01/2016 09:00         0.0
# 3  01/01/2016 10:00         0.0
# 4  01/01/2016 12:00         0.0

# %%
r3=rain3[-513:]

r3.plot(x='date' , y='prediction')
plt.title('Rainfall Prediction (Window size 3)')
plt.xlabel('Date & time')
plt.ylabel('Rainfall (in mm)')
plt.xticks(rotation=45)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text xticklabel objects>)

# %%
rain4=pd.read_csv('D:\\Scalable system programming\\Output_new\\rain_4.csv')
print(rain4.head())
# Out:
#                date  prediction
# 0  01/01/2016 07:00         0.0
# 1  01/01/2016 08:00         0.0
# 2  01/01/2016 09:00         0.0
# 3  01/01/2016 10:00         0.0
# 4  01/01/2016 12:00         0.0

# %%
r4=rain4[-513:]

r4.plot(x='date' , y='prediction')
plt.title('Rainfall Predciton (Window size 4)')
plt.xlabel('Date & time')
plt.ylabel('Rainfall (in mm)')
plt.xticks(rotation=45)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text xticklabel objects>)

# %%
actual_rain= df['rain']

# %%
rain_2=rain2['prediction']

# %%
rain_3=rain3['prediction']

# %%
rain_4=rain4['prediction']

# %%
from dm_test import dm_test
print("Comparison of MSE")
rain1=dm_test(actual_rain,rain_3,rain_2,h = 1, crit="MSE")
print("Comparison between window size 2 and 3",rain1)
rain2=dm_test(actual_rain,rain_4,rain_3,h = 1, crit="MSE")
print("Comparison between window size 3 and 4",rain2)
rain3=dm_test(actual_rain,rain_4,rain_2,h = 1, crit="MSE")
print("Comparison between window size 4 and 2",rain3)
# Out:
# Comparison of MSE
# Comparison between window size 2 and 3 dm_return(DM=0.6325032422461133, p_value=0.5270632827982025)
# Comparison between window size 3 and 4 dm_return(DM=0.5547714986799667, p_value=0.5790554191165085)
# Comparison between window size 4 and 2 dm_return(DM=0.666729659398491, p_value=0.504950353051624)

# %%
print("Comparison of MAD")
rain1=dm_test(actual_rain,rain_3,rain_2,h = 1, crit="MAD")
print("Comparison between window size 2 and 3",rain1)
rain2=dm_test(actual_rain,rain_4,rain_3,h = 1, crit="MAD")
print("Comparison between window size 3 and 4",rain2)
rain3=dm_test(actual_rain,rain_4,rain_2,h = 1, crit="MAD")
print("Comparison between window size 4 and 2",rain3)
# Out:
# Comparison of MAD
# Comparison between window size 2 and 3 dm_return(DM=0.9054492306770213, p_value=0.36523527695488056)
# Comparison between window size 3 and 4 dm_return(DM=0.6806224396830804, p_value=0.4961160822058003)
# Comparison between window size 4 and 2 dm_return(DM=1.1322552736643137, p_value=0.2575368755907107)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error(actual_rain, rain_2)
rmse = sqrt(mse)
print("The RMSE value of Rain for window size 2 is",rmse)
mse1 = mean_squared_error(actual_rain, rain_3)
rmse1 = sqrt(mse1)
print("The RMSE value of Rain for window size 3 is",rmse1)
mse2 = mean_squared_error(actual_rain, rain_4)
rmse2 = sqrt(mse2)
print("The RMSE value of Rain for window size 4 is",rmse2)
# Out:
# The RMSE value of Rain for window size 2 is 41.6550618592486
# The RMSE value of Rain for window size 3 is 48.099424062426785
# The RMSE value of Rain for window size 4 is 51.01740526497363

# %%
mae = mean_absolute_error(actual_rain, rain_2)
print("The MAE value of Rain for window size 2 is",mae)
mae1 = mean_absolute_error(actual_rain, rain_3)
print("The MAE value of Rain for window size 3 is",mae1)
mae2 = mean_absolute_error(actual_rain, rain_4)
print("The MAE value of Rain for window size 4 is",mae2)
# Out:
# The MAE value of Rain for window size 2 is 0.3718446845941191
# The MAE value of Rain for window size 3 is 0.502322909560191
# The MAE value of Rain for window size 4 is 0.5716768391196638
